# %% [markdown]
# # Preprocessing der Trainingsdaten

# %%
import pandas as pd
import os
import numpy as np

print("Current working directory: " + os.getcwd())
train_data_path = os.path.join(os.getcwd(), "resources\\train_data\\")
print("Train data path: " + train_data_path)
# Out:
# Current working directory: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF
# Train data path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\

# %%
data1_path = os.path.join(train_data_path, "2022-06-29-05-12-03-train_data_dump.csv")
print("data1 path: " + data1_path)
data_set1 = pd.read_csv(data1_path, header = None)
# Entferne rho^3
data1_nonDuplicates = ~np.any(data_set1 == 1000,axis = 1)
data_set1 = data_set1.loc[data1_nonDuplicates] 
print(data_set1.shape)
data_set1.head()
# Out:
# data1 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-05-12-03-train_data_dump.csv
# (13179, 4801)
#       0        1        2        3        4        5        6        7     \
# 0  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 1  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 2        1        1        1        1        1        1        1        1
# 3  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 5        1        1        1        1        1        1        1        1
#
#       8        9     ...     4791     4792     4793     4794     4795  \
# 0  1000000  1000000  ...        1        1        1        1        1
# 1  1000000  1000000  ...  1000000  1000000  1000000  1000000  1000000
# 2        1        1  ...        1        1        1        1        1
# 3  1000000  1000000  ...        1        1        1        1        1
# 5        1        1  ...        1        1        1        1        1
#
#       4796     4797     4798     4799  4800
# 0        1        1        1        1     0
# 1  1000000  1000000  1000000  1000000     0
# 2        1        1        1        1     0
# 3        1        1        1        1     0
# 5        1        1        1        1     0
#
# [5 rows x 4801 columns]

# %%
data2_path = os.path.join(train_data_path, "2022-06-29-02-31-52-train_data_dump.csv")
print("data2 path: " + data2_path)
data_set2 = pd.read_csv(data2_path, header = None)
# Entferne rho^3
data2_nonDuplicates = ~np.any(data_set2 == 1000,axis = 1)
data_set2 = data_set2.loc[data2_nonDuplicates] 
print(data_set2.shape)
data_set2.head()
# Out:
# data2 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-02-31-52-train_data_dump.csv
# (24008, 4801)
#       0        1        2        3        4        5        6        7     \
# 0  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 1  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 2        1        1        1        1        1        1        1        1
# 3  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 4        1        1        1        1        1        1        1        1
#
#       8        9     ...     4791     4792     4793     4794     4795  \
# 0  1000000  1000000  ...        1        1        1        1        1
# 1  1000000  1000000  ...  1000000  1000000  1000000  1000000  1000000
# 2        1        1  ...        1        1        1        1        1
# 3  1000000  1000000  ...        1        1        1        1        1
# 4        1        1  ...  1000000  1000000  1000000  1000000  1000000
#
#       4796     4797     4798     4799  4800
# 0        1        1        1        1     0
# 1  1000000  1000000  1000000  1000000     0
# 2        1        1        1        1     0
# 3        1        1        1        1     0
# 4  1000000  1000000  1000000  1000000     0
#
# [5 rows x 4801 columns]

# %%
data3_path = os.path.join(train_data_path, "2022-06-29-15-19-21-train_data_dump.csv")
print("data1 path: " + data3_path)
data_set3 = pd.read_csv(data3_path, header = None)
# Entferne rho^3
data3_nonDuplicates = ~np.any(data_set3 == 1000,axis = 1)
data_set3 = data_set3.loc[data3_nonDuplicates] 
print(data_set3.shape)
data_set3.head()
# Out:
# data1 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-15-19-21-train_data_dump.csv
# (24008, 4801)
#       0        1        2        3        4        5        6        7     \
# 0  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 1  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 2        1        1        1        1        1        1        1        1
# 3  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 4        1        1        1        1        1        1        1        1
#
#       8        9     ...     4791     4792     4793     4794     4795  \
# 0  1000000  1000000  ...        1        1        1        1        1
# 1  1000000  1000000  ...  1000000  1000000  1000000  1000000  1000000
# 2        1        1  ...        1        1        1        1        1
# 3  1000000  1000000  ...        1        1        1        1        1
# 4        1        1  ...  1000000  1000000  1000000  1000000  1000000
#
#       4796     4797     4798     4799  4800
# 0        1        1        1        1     0
# 1  1000000  1000000  1000000  1000000     0
# 2        1        1        1        1     0
# 3        1        1        1        1     0
# 4  1000000  1000000  1000000  1000000     0
#
# [5 rows x 4801 columns]

# %%
param1_path = os.path.join(train_data_path, "2022-06-29-05-14-01-parameter_dump.csv")
print("param1 path: " + param1_path)
parameter_set1 = pd.read_csv(param1_path, names = ["coefficentType","parameterNames","parameterValues"])
print(parameter_set1.shape)
parameter_set1.head()
# Out:
# param1 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-05-14-01-parameter_dump.csv
# (7203, 3)
#   coefficentType                                     parameterNames  \
# 0       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 1       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 2       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 3          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
# 4          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
#
#             parameterValues
# 0     6,10,1,1000000,0,0,,,
# 1        6,10,1000,1,0,0,,,
# 2  6,10,1000000,1000,0,0,,,
# 3         2,5,1000,1,18,,,,
# 4     -2,3,1000000,1,16,,,,

# %%
param2_path = os.path.join(train_data_path, "2022-06-29-02-32-41-parameter_dump.csv")
print("param2 path: " + param2_path)
parameter_set2 = pd.read_csv(param2_path, names = ["coefficentType","parameterNames","parameterValues"])
print(parameter_set2.shape)
parameter_set2.head()
# Out:
# param2 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-02-32-41-parameter_dump.csv
# (6002, 3)
#   coefficentType                                     parameterNames  \
# 0       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 1       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 2          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
# 3          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
# 4          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
#
#          parameterValues
# 0  6,10,1,1000000,0,0,,,
# 1  6,10,1000000,1,0,0,,,
# 2   -2,4,1000000,1,8,,,,
# 3   -1,4,1,1000000,8,,,,
# 4    4,3,1000000,1,0,,,,

# %%
param3_path = os.path.join(train_data_path, "2022-06-29-15-21-37-parameter_dump.csv")
print("param1 path: " + param3_path)
parameter_set3 = pd.read_csv(param3_path, names = ["coefficentType","parameterNames","parameterValues"])
print(parameter_set3.shape)
parameter_set3.head()
# Out:
# param1 path: C:\Users\Valentin\Documents\10. Semester\WR2\Projekt 3 - FNN CLF\WR-2-3-FFN-CLF\resources\train_data\2022-06-29-15-21-37-parameter_dump.csv
# (6002, 3)
#   coefficentType                                     parameterNames  \
# 0       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 1       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 2          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
# 3          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
# 4          Strip           height,nStrips,rhoMin,rhoMax,indexShifty
#
#          parameterValues
# 0  6,10,1,1000000,0,0,,,
# 1  6,10,1000000,1,0,0,,,
# 2          0,2,1,1,4,,,,
# 3  -1,3,1000000,1,16,,,,
# 4    0,3,1000000,1,0,,,,

# %%
df = pd.concat([data_set1,data_set2,data_set3],axis = 0,ignore_index = True)
df.shape
# Out:
# (61195, 4801)

# %%
param_df = pd.concat([parameter_set1.loc[data1_nonDuplicates],
                      parameter_set2.loc[data2_nonDuplicates],
                      parameter_set3.loc[data3_nonDuplicates]],axis = 0,ignore_index = True)
param_df = param_df.loc[param_df.index.repeat(4)].reset_index(drop=True)
param_df.head()
# Out:
#   coefficentType                                     parameterNames  \
# 0       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 1       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 2       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 3       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 4       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
#
#          parameterValues
# 0  6,10,1,1000000,0,0,,,
# 1  6,10,1,1000000,0,0,,,
# 2  6,10,1,1000000,0,0,,,
# 3  6,10,1,1000000,0,0,,,
# 4     6,10,1000,1,0,0,,,

# %% [markdown]
# ## Duplikate entfernen

# %%
duplicate_rows = df.duplicated()
print("shape with duplicates: ")
print(df.shape)
df = df.loc[~duplicate_rows,]
print("shape without duplicates: ")
print(df.shape)
print("Percentage of datapoints lost: " + str((100*sum(duplicate_rows)/len(duplicate_rows))) + "\%")
# Out:
# shape with duplicates:
# (61195, 4801)
# shape without duplicates:
# (20003, 4801)
# Percentage of datapoints lost: 67.31268894517525\%

# %%
# Zeige Duplikate
df.loc[~duplicate_rows,].head()
# Out:
#       0        1        2        3        4        5        6        7     \
# 0  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 1  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
# 2        1        1        1        1        1        1        1        1
# 6  1000000  1000000  1000000  1000000  1000000  1000000        1        1
# 7  1000000  1000000  1000000  1000000  1000000  1000000  1000000  1000000
#
#       8        9     ...     4791     4792     4793     4794     4795  \
# 0  1000000  1000000  ...        1        1        1        1        1
# 1  1000000  1000000  ...  1000000  1000000  1000000  1000000  1000000
# 2        1        1  ...        1        1        1        1        1
# 6        1  1000000  ...  1000000  1000000  1000000  1000000        1
# 7  1000000  1000000  ...  1000000  1000000  1000000  1000000  1000000
#
#       4796     4797     4798     4799  4800
# 0        1        1        1        1     0
# 1  1000000  1000000  1000000  1000000     0
# 2        1        1        1        1     0
# 6        1  1000000  1000000  1000000     1
# 7  1000000  1000000  1000000  1000000     0
#
# [5 rows x 4801 columns]

# %%
df.iloc[:,-1].describe()
# Out:
# count    20003.00000
# mean         0.19992
# std          0.39995
# min          0.00000
# 25%          0.00000
# 50%          0.00000
# 75%          0.00000
# max          1.00000
# Name: 4800, dtype: float64

# %%
print("shape with duplicates: ")
print(param_df.shape)
param_df = param_df.loc[~duplicate_rows,]
print("shape without duplicates: ")
print(param_df.shape)
param_df.head()
# Out:
# shape with duplicates:
# (61076, 3)
# shape without duplicates:
# (19952, 3)
#   coefficentType                                     parameterNames  \
# 0       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 1       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 2       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 6       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
# 7       Constant  affectedSubdomains,rhoMin,rhoMax,indexShiftx,i...
#
#          parameterValues
# 0  6,10,1,1000000,0,0,,,
# 1  6,10,1,1000000,0,0,,,
# 2  6,10,1,1000000,0,0,,,
# 6     6,10,1000,1,0,0,,,
# 7     6,10,1000,1,0,0,,,

# %%
# Exportiere
# df.to_csv(os.path.join(train_data_path, "training_dataset_ver1.csv"),index = False, header = False)
# param_df.to_csv(os.path.join(train_data_path, "training_dataset_ver1_parameters.csv"),index = False, header = False)
